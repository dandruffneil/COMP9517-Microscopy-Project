# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os

from scipy import ndimage as ndi
from skimage.morphology import watershed
from skimage.feature import peak_local_max
from sklearn.cluster import MeanShift

from PIL import Image

# %%
IMAGE_FOLDER = "../Sequences/01/"
n_images = len(os.listdir(IMAGE_FOLDER))
# images are 1100 x 700

# %%
# Task 1-1: Segment all cells
# i = 1
# for image_file in os.listdir(IMAGE_FOLDER):
#     image_path = os.path.join(IMAGE_FOLDER, image_file)
    
#     img = cv2.imread(image_path)
    
#     plt.imshow(img)
#     i += 1
image_path = os.path.join(IMAGE_FOLDER, os.listdir(IMAGE_FOLDER)[13])
print(image_path)
img = cv2.imread(image_path, -1)
plt.imshow(img, 'gray')
plt.title('Original Image')
plt.show()
# Out:
# ../Sequences/01/t013.tif

# %%
# Testing min-max filter to remove background
img_test = img.copy()
plt.imshow(img, 'gray'), plt.title('Original')
plt.show()

kernel = np.ones((50,50),np.uint16)
img_erosion = cv2.erode(img_test, kernel, iterations=3)
img_dilated = cv2.dilate(img_erosion, kernel, iterations=3)

plt.subplot(1,2,1),plt.imshow(img_erosion, 'gray'), plt.title('Eroded (min-filter)')
plt.subplot(1,2,2),plt.imshow(img_dilated, 'gray'), plt.title('Dilated again (min-max filter)')
plt.show()

img_output = img_test.copy()

for i in range(len(img_test)):
    for j in range(len(img_test[0])):
        i_pixel = int(img_test[i][j])
        b_pixel = int(img_dilated[i][j])
        if b_pixel >= i_pixel:
            img_output[i][j] = 0
        else:
            img_output[i][j] = i_pixel - b_pixel

plt.imshow(img_output, 'gray'), plt.title('Output')
plt.show()
print(img_output)
# Out:
# [[30 31 33 ... 43 44 35]
#  [30 27 38 ... 38 34 36]
#  [35 36 42 ... 44 37 36]
#  ...
#  [15 24 27 ... 32 31 28]
#  [22 21 22 ... 32 24 33]
#  [21 19 24 ... 30 37 28]]

# %%
# Contrast stretching
img_test = img_output.copy()

min_pixel = np.min(img_test)
max_pixel = np.max(img_test)
print(f'min: {min_pixel}, max: {max_pixel}')

for i in range(len(img_test)):
    for j in range(len(img_test[0])):
        img_test[i][j] = (img_test[i][j] - min_pixel)/(max_pixel-min_pixel)*65535

plt.imshow(img_test, 'gray'), plt.title('constrast stretched')
plt.show()
min_pixel = np.min(img_test)
max_pixel = np.max(img_test)
print(f'min: {min_pixel}, max: {max_pixel}')
img_output = img_test.copy()
# Out:
# min: 0, max: 3818
# min: 0, max: 65535

# %%
img_blur = cv2.GaussianBlur(img_output, (5,5), cv2.BORDER_DEFAULT)
img_blur = cv2.GaussianBlur(img_blur, (5,5), cv2.BORDER_DEFAULT)
# img_blur = cv2.medianBlur(img_output, 7)
# img_blur = cv2.medianBlur(img_blur, 7)
plt.imshow(img_blur, 'gray'), plt.title('Image blurred')
plt.show()
img_output = img_blur.copy()
print(img_output)
# Out:
# [[597 599 604 ... 708 704 702]
#  [593 596 601 ... 719 716 714]
#  [588 592 597 ... 753 749 747]
#  ...
#  [386 390 401 ... 519 511 511]
#  [390 393 401 ... 531 519 517]
#  [387 390 396 ... 534 523 521]]

# %%
# Open then close operation
img_test = img_output.copy()

kernel = np.ones((5,5),np.uint16)
img1 = cv2.erode(img_test, kernel, iterations=1)
img2 = cv2.dilate(img1, kernel, iterations=1)
img3 = cv2.dilate(img2, kernel, iterations=1)
img4 = cv2.erode(img3, kernel, iterations=1)
plt.subplot(1,2,1),plt.imshow(img_test, 'gray'), plt.title('Original')
plt.subplot(1,2,2),plt.imshow(img4, 'gray'), plt.title('Opening then closing')
plt.show()

img_output = img4.copy()

# %%
img_test = img_output.astype('uint8')
# img_th = cv2.adaptiveThreshold(img_test, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 25, 2)
_, img_th = cv2.threshold(img_test, 120, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(img_th, 'gray'), plt.title('Adaptive thresholded')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-173-a68887c96864> in <module>
#       1 img_test = img_output.copy()
#       2 # img_th = cv2.adaptiveThreshold(img_test, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 25, 2)
# ----> 3 _, img_th = cv2.threshold(img_test, 120, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#       4
#       5 plt.imshow(img_th, 'gray'), plt.title('Adaptive thresholded')
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\imgproc\src\thresh.cpp:1406: error: (-215:Assertion failed) src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function 'cv::threshold'

# %%
img_test = img_output.copy()
bg_pixel = np.bincount(img_test.ravel()).argmax()
print(f'Background pixel value is {bg_pixel}')

_, img_th1 = cv2.threshold(img_test, bg_pixel+1, 65535, 0)
plt.imshow(img_th1, cmap='gray'), plt.title(f'Thresholded at {bg_pixel+1}')
plt.show()

_, img_th2 = cv2.threshold(img_test, bg_pixel, 65535, 0)
plt.imshow(img_th2, cmap='gray'), plt.title(f'Thresholded at {bg_pixel}')
plt.show()

_, img_th3 = cv2.threshold(img_test, bg_pixel-1, 65535, 0)
plt.imshow(img_th3, cmap='gray'), plt.title(f'Thresholded at {bg_pixel-1}')
plt.show()
# Out:
# Background pixel value is 33

# %%
_, contours, _ = cv2.findContours(img_th, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))
img_contour = cv2.drawContours(img, contours, -1, (0,255,0), 3)
plt.imshow(img_contour, 'gray')
plt.show()
# Out:
# 1625

# %%
# Out:
# 1625
